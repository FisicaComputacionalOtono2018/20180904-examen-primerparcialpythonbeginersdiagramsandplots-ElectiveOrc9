# %%
#Author: Angel Octavio Parada Flores.
#Fecha: 4/09/18.
#Examen (1ra Unidad) - 1er Problema.
x=1
#Le da 1 valor a x.
while x<=5:
#Mientras x sea menor o igual que 5, el programa va a correr lo que sigue.
  if x%3!=0:
#Pregunta si x no es divisible entre 3.
    print(x)
#En caso de que no lo sea, el programa le suma 2 a la variable, en caso contrario la imprime y después le suma 2.
  x=x+2
#El programa se repite hasta que x sea mayor o igual a 5.
# Out:
# 1
# 5

# %%
#Author: Angel Octavio Parada Flores
#Fecha: 4/09/18.
#Examen (1ra Unidad) - 2do Problema.
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
from scipy.optimize import brentq
print('Grafica de la funcion: -x**2+3*x')
x = Symbol('x')

def f(a):
 return -a**2+3*a
b=np.arange(-5, 8, 0.1)

c=diff(-x**2+3*x)
print('La derivada de la funcion es', c)


plt.plot(b, f(b))
plt.show()
print('La funcion cambia de signo en cuando -x**2+3*x=0, esto es en x=3/2=1.5')
# Out:
# Grafica de la funcion: -x**2+3*x
# ('La derivada de la funcion es', -2*x + 3)
# La funcion cambia de signo en cuando -x**2+3*x=0, esto es en x=3/2=1.5

# %%
#Author: Angel Octavio Parada Flores
#Fecha: 4/09/18.
#Examen (1ra Unidad) - 3er Problema.
import matplotlib.pyplot as plt
print('Grafica de una funcion de la forma a0x⁰+a1x¹+a2x²')
a0 = float(input('Coeficiente a0: '))
a1 = float(input('Coeficiente a1: '))
a2 = float(input('Coeficiente a2: '))
def f(x):
 return a0*x**0+a1*x**1+a2*x**2
x=np.arange(-2, 4, 0.1)

plt.plot(x, f(x))
plt.show()
# Out:
# Grafica de una funcion de la forma a0x⁰+a1x¹+a2x²
# Coeficiente a0: 0
# Coeficiente a1: 0
# Coeficiente a2: 1

# %%
#Author: Angel Octavio Parada Flores
#Fecha: 4/09/18.
#Examen (1ra Unidad) - 3er Problema (Intendo de polinomio de grado n). }
import matplotlib.pyplot as plt
import numpy as np
n = int(input('Grado del polinomio: '))
def f(x): 
 for i in range (0, n+1):
  x = x + x**i
 return x
  
x=np.arange(-2, 4, 0.1)

plt.plot(x, f(x))
plt.show()
# Out:
# Grado del polinomio: 3
